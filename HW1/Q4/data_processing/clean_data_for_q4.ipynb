# %%
import time
import sys
from pathlib import Path

sys.path.append('../..')
from utils import TAQDataProcessorPolars

# %%
MRNA_TRADES = "../data/TAQ_MRNA_trades_sep2025.csv"
MRNA_QUOTES = "../data/TAQ_MRNA_quotes_sep2025.csv"
MRNA_TRADES_OUTPUT = "../data/MRNA_trades_polars.parquet"
MRNA_QUOTES_OUTPUT = "../data/MRNA_quotes_polars.parquet"

polars_processor = TAQDataProcessorPolars()
start = time.time()
polars_processor.process_trades(MRNA_TRADES, MRNA_TRADES_OUTPUT)
polars_time = time.time() - start
print(f"  Trades processing time: {polars_time:.2f} seconds")

polars_processor = TAQDataProcessorPolars()
start = time.time()
polars_processor.process_quotes(MRNA_QUOTES, MRNA_QUOTES_OUTPUT)
polars_time = time.time() - start
print(f"  Quotes processing time: {polars_time:.2f} seconds")
# Out:
#   Time: 2.50 seconds
#
# Polars Processing:
#   Time: 34.85 seconds

# %%
TRVG_TRADES = "../data/TAQ_TRVG_trades_sep2025.csv"
TRVG_QUOTES = "../data/TAQ_TRVG_quotes_sep2025.csv"
TRVG_TRADES_OUTPUT = "../data/TRVG_trades_polars.parquet"
TRVG_QUOTES_OUTPUT = "../data/TRVG_quotes_polars.parquet"

polars_processor = TAQDataProcessorPolars()
start = time.time()
polars_processor.process_trades(TRVG_TRADES, TRVG_TRADES_OUTPUT)
polars_time = time.time() - start
print(f"  Trades processing time: {polars_time:.2f} seconds")

polars_processor = TAQDataProcessorPolars()
start = time.time()
polars_processor.process_quotes(TRVG_QUOTES, TRVG_QUOTES_OUTPUT)
polars_time = time.time() - start
print(f"  Quotes processing time: {polars_time:.2f} seconds")
# Out:
#   Trades processing time: 0.27 seconds
#   Quotes processing time: 0.07 seconds
