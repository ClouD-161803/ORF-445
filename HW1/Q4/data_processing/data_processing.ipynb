# %% [markdown]
# # TAQ Data Processor Performance Comparison
#
# Comparing processing times for Pandas vs Polars implementations on MRNA stock data.

# %%
import time
import sys
from pathlib import Path

sys.path.append('../..')
from utils import TAQDataProcessorPandas, TAQDataProcessorPolars

# %% [markdown]
# ## Test Configuration

# %%
# Paths to MRNA data (relative to notebook location in Q4/data_processing/)
MRNA_TRADES = "../data/TAQ_MRNA_trades_sep2025.csv"
MRNA_QUOTES = "../data/TAQ_MRNA_quotes_sep2025.csv"

# Output paths
MRNA_TRADES_PANDAS_OUTPUT = "./results/MRNA_trades_pandas.parquet"
MRNA_TRADES_POLARS_OUTPUT = "./results/MRNA_trades_polars.parquet"
MRNA_QUOTES_PANDAS_OUTPUT = "./results/MRNA_quotes_pandas.parquet"
MRNA_QUOTES_POLARS_OUTPUT = "./results/MRNA_quotes_polars.parquet"

# Create results directory
Path("./results").mkdir(parents=True, exist_ok=True)

print("Configuration ready:")
print(f"  Trades input: {MRNA_TRADES}")
print(f"  Quotes input: {MRNA_QUOTES}")
print(f"  Output directory: ./results/")
# Out:
# Configuration ready:
#   Trades input: ../data/TAQ_MRNA_trades_sep2025.csv
#   Quotes input: ../data/TAQ_MRNA_quotes_sep2025.csv
#   Output directory: ./results/

# %% [markdown]
# ## Trade Data Processing Comparison

# %%
print("\n" + "="*70)
print("TESTING TRADE DATA PROCESSING")
print("="*70)

# Pandas implementation
print("\nPandas Processing:")
pandas_processor = TAQDataProcessorPandas()
start = time.time()
pandas_processor.process_trades(MRNA_TRADES, MRNA_TRADES_PANDAS_OUTPUT)
pandas_time = time.time() - start
print(f"  Time: {pandas_time:.2f} seconds")

# Polars implementation
print("\nPolars Processing:")
polars_processor = TAQDataProcessorPolars()
start = time.time()
polars_processor.process_trades(MRNA_TRADES, MRNA_TRADES_POLARS_OUTPUT)
polars_time = time.time() - start
print(f"  Time: {polars_time:.2f} seconds")

# Comparison
speedup = pandas_time / polars_time
print(f"\nComparison:")
print(f"  Speedup (Pandas time / Polars time): {speedup:.2f}x")
if speedup > 1:
    print(f"  ✓ Polars is {speedup:.2f}x faster")
else:
    print(f"  ✓ Pandas is {1/speedup:.2f}x faster")
# Out:
# ======================================================================
# TESTING TRADE DATA PROCESSING
# ======================================================================
#
# Pandas Processing:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 9
#       7 pandas_processor = TAQDataProcessorPandas()
#       8 start = time.time()
# ----> 9 pandas_processor.process_trades(MRNA_TRADES, MRNA_TRADES_PANDAS_OUTPUT)
#      10 pandas_time = time.time() - start
#      11 print(f"  Time: {pandas_time:.2f} seconds")
#
# File c:\Users\cvest\Claudio\Princeton\4th Year\ORF 445\HW1\Q4\data_processing\../..\utils.py:43, in TAQDataProcessorPandas.process_trades(self, input_path, output_path, use_cols)
#      41 df = pd.read_csv(input_path, usecols=use_cols, engine='pyarrow')
#      42 df = df[(df['PRICE'] > 0) & (df['SIZE'] > 0)]
# ---> 43 df = self._apply_timestamps(df).sort_index()
#      44 self.save_to_parquet(df, output_path)
#
# File c:\Users\cvest\Claudio\Princeton\4th Year\ORF 445\HW1\Q4\data_processing\../..\utils.py:26, in TAQDataProcessorPandas._apply_timestamps(self, df)
#      24 def _apply_timestamps(self, df: pd.DataFrame) -> pd.DataFrame:
#      25     dt_string = df['DATE'].astype(str) + 'T' + df['TIME_M']
# ---> 26     df['TIMESTAMP'] = pd.to_datetime(dt_string)
#      27     df = df.drop(columns=['DATE', 'TIME_M']).set_index('TIMESTAMP')
#      28     df = df.tz_localize(self.tz_local, ambiguous='infer', nonexistent='shift_forward')
#
# File c:\Users\cvest\anaconda3\envs\orf445\Lib\site-packages\pandas\core\tools\datetimes.py:1040, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1038         result = arg.map(cache_array)
#    1039     else:
# -> 1040         values = convert_listlike(arg._values, format)
#    1041         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1042 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\cvest\anaconda3\envs\orf445\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File c:\Users\cvest\anaconda3\envs\orf445\Lib\site-packages\pandas\core\tools\datetimes.py:470, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     459 def _array_strptime_with_fallback(
#     460     arg,
#     461     name,
#    (...)    465     errors: str,
#     466 ) -> Index:
#     467     """
#     468     Call array_strptime, with fallback behavior depending on 'errors'.
#     469     """
# --> 470     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     471     if tz_out is not None:
#     472         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:563, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:511, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:617, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "15/09/2025T4:00:00.027309648" doesn't match format "%m/%d/%YT%H:%M:%S.%f". You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %% [markdown]
# ## Quote Data Processing Comparison

# %%
print("\n" + "="*70)
print("TESTING QUOTE DATA PROCESSING")
print("="*70)

# Pandas implementation
print("\nPandas Processing:")
pandas_processor = TAQDataProcessorPandas()
start = time.time()
pandas_processor.process_quotes(MRNA_QUOTES, MRNA_QUOTES_PANDAS_OUTPUT)
pandas_time = time.time() - start
print(f"  Time: {pandas_time:.2f} seconds")

# Polars implementation
print("\nPolars Processing:")
polars_processor = TAQDataProcessorPolars()
start = time.time()
polars_processor.process_quotes(MRNA_QUOTES, MRNA_QUOTES_POLARS_OUTPUT)
polars_time = time.time() - start
print(f"  Time: {polars_time:.2f} seconds")

# Comparison
speedup = pandas_time / polars_time
print(f"\nComparison:")
print(f"  Speedup (Pandas time / Polars time): {speedup:.2f}x")
if speedup > 1:
    print(f"  ✓ Polars is {speedup:.2f}x faster")
else:
    print(f"  ✓ Pandas is {1/speedup:.2f}x faster")

# %% [markdown]
# ## Summary

# %%
print("\n" + "="*70)
print("PERFORMANCE TEST COMPLETE")
print("="*70)
print("\nOutput files generated:")
print(f"  Pandas trades:  {MRNA_TRADES_PANDAS_OUTPUT}")
print(f"  Polars trades:  {MRNA_TRADES_POLARS_OUTPUT}")
print(f"  Pandas quotes:  {MRNA_QUOTES_PANDAS_OUTPUT}")
print(f"  Polars quotes:  {MRNA_QUOTES_POLARS_OUTPUT}")
